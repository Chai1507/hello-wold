# %%
# import the data set
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\ABC\Desktop\weatherHistory.csv")
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
# dataset.info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  int64
#  8   Visibility (km)           96453 non-null  float64
#  9   Pressure (millibars)      96453 non-null  float64
#  10  Daily Summary             96453 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 8.1+ MB

# %%
# dataset.head()
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# ...

# %%
# dataset.index
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
# dataset name["col name"].unique()
data["Precip Type"].unique()
# Out:
# array(['rain', 'snow', nan], dtype=object)

# %%
# show data
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
# dataset name["col name"].nunique()
data["Wind Speed (km/h)"].nunique()
# Out:
# 2484

# %%
# dataset name["col name"].unique()
data["Wind Speed (km/h)"].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %%
# show data
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
# value_counts()
data["Precip Type"].value_counts()
# Out:
# rain    85224
# snow    10712
# Name: Precip Type, dtype: int64

# %%
# using filtering
data[data["Precip Type"] == "snow"]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 1562   2006-12-13 02:00:00.000 +0100          Foggy        snow
# 1563   2006-12-13 03:00:00.000 +0100          Foggy        snow
# 1564   2006-12-13 04:00:00.000 +0100          Foggy        snow
# 1565   2006-12-13 05:00:00.000 +0100          Foggy        snow
# 1566   2006-12-13 06:00:00.000 +0100          Foggy        snow
# ...                              ...            ...         ...
# 93265  2016-03-28 05:00:00.000 +0200          Foggy        snow
# 93266  2016-03-28 06:00:00.000 +0200          Foggy        snow
# 93267  2016-03-28 07:00:00.000 +0200          Foggy        snow
# 93311  2016-03-03 03:00:00.000 +0100  Partly Cloudy        snow
# 93506  2016-03-09 06:00:00.000 +0100          Foggy        snow
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1562         -0.483333                 -4.150000      1.00            11.0929
# ...

# %%
# groupby()
data.groupby("Precip Type").get_group("snow")
# Out:
#                       Formatted Date        Summary Precip Type  \
# 1562   2006-12-13 02:00:00.000 +0100          Foggy        snow
# 1563   2006-12-13 03:00:00.000 +0100          Foggy        snow
# 1564   2006-12-13 04:00:00.000 +0100          Foggy        snow
# 1565   2006-12-13 05:00:00.000 +0100          Foggy        snow
# 1566   2006-12-13 06:00:00.000 +0100          Foggy        snow
# ...                              ...            ...         ...
# 93265  2016-03-28 05:00:00.000 +0200          Foggy        snow
# 93266  2016-03-28 06:00:00.000 +0200          Foggy        snow
# 93267  2016-03-28 07:00:00.000 +0200          Foggy        snow
# 93311  2016-03-03 03:00:00.000 +0100  Partly Cloudy        snow
# 93506  2016-03-09 06:00:00.000 +0100          Foggy        snow
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1562         -0.483333                 -4.150000      1.00            11.0929
# ...

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data[data["Wind Speed (km/h)"] == 14.1197]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 618    2006-04-05 18:00:00.000 +0200       Overcast        rain
# 646    2006-04-06 22:00:00.000 +0200       Overcast        rain
# 1264   2006-08-03 16:00:00.000 +0200  Mostly Cloudy        rain
# 1885   2006-12-25 13:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 94761  2016-11-28 13:00:00.000 +0100  Mostly Cloudy        rain
# 94784  2016-11-29 12:00:00.000 +0100  Mostly Cloudy        rain
# 94785  2016-11-29 13:00:00.000 +0100  Mostly Cloudy        rain
# 94833  2016-11-30 13:00:00.000 +0100  Mostly Cloudy        rain
# 96371  2016-09-06 14:00:00.000 +0200  Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
# isnull()
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data.rename(columns={"Precip Type":"Wether Condition"}, inplace=True)

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Wether Condition  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy             rain
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy             rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                     251          15.8263               1015.13
# 1                     259          15.8263               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data["Visibility (km)"].mean()
# Out:
# 10.347324929237148

# %%
data["Pressure (millibars)"].std()
# Out:
# 116.96990568258147

# %%
data["Humidity"].var()
# Out:
# 0.03820959171844407

# %%
# value_counts()
#data.head(2)
data["Wether Condition"].value_counts()
# Out:
# rain    85224
# snow    10712
# Name: Wether Condition, dtype: int64

# %%
# using filtering
data[data["Wether Condition"]=="rain"]
# Out:
#                       Formatted Date        Summary Wether Condition  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy             rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy             rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy             rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy             rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy             rain
# ...                              ...            ...              ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy             rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy             rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy             rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy             rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy             rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
# str.contains()
data["Wether Condition"].str.contains("rain")
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 96448    True
# 96449    True
# 96450    True
# 96451    True
# 96452    True
# Name: Wether Condition, Length: 96453, dtype: object

# %%
data[(data["Wind Speed (km/h)"] > 11.0446) & (data["Visibility (km)"] > 15.8263)]
# Out:
#                       Formatted Date        Summary Wether Condition  \
# 142    2006-04-14 22:00:00.000 +0200  Mostly Cloudy             rain
# 742    2006-08-01 22:00:00.000 +0200  Partly Cloudy             rain
# 927    2006-08-17 15:00:00.000 +0200          Clear             rain
# 1099   2006-08-23 19:00:00.000 +0200  Partly Cloudy             rain
# 2781   2006-02-05 21:00:00.000 +0100          Clear             snow
# ...                              ...            ...              ...
# 96441  2016-09-09 12:00:00.000 +0200  Partly Cloudy             rain
# 96442  2016-09-09 13:00:00.000 +0200  Partly Cloudy             rain
# 96444  2016-09-09 15:00:00.000 +0200  Partly Cloudy             rain
# 96445  2016-09-09 16:00:00.000 +0200  Partly Cloudy             rain
# 96447  2016-09-09 18:00:00.000 +0200  Partly Cloudy             rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
data.groupby("Wether Condition").mean()
# Out:
#                   Temperature (C)  Apparent Temperature (C)  Humidity  \
# Wether Condition
# rain                    13.852989                 13.013425  0.718699
# snow                    -3.270885                 -6.249847  0.863263
#
#                   Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# Wether Condition
# rain                      10.971219              189.123170        10.830711
# snow                       9.481998              174.754294         6.636570
#
#                   Pressure (millibars)
# Wether Condition
# rain                       1002.764548
# snow                       1006.216970

# %%
data.groupby("Wether Condition").min()
# Out:
#                                  Formatted Date Summary  Temperature (C)  \
# Wether Condition
# rain              2006-01-01 00:00:00.000 +0100  Breezy         0.005556
# snow              2006-01-07 19:00:00.000 +0100  Breezy       -21.822222
#
#                   Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# Wether Condition
# rain                             -7.550000       0.0                0.0
# snow                            -27.716667       0.0                0.0
#
#                   Wind Bearing (degrees)  Visibility (km)  \
# Wether Condition
# rain                                   0              0.0
# snow                                   0              0.0
#
#                   Pressure (millibars)  \
# Wether Condition
# rain                               0.0
# snow                               0.0
#
#                                               Daily Summary
# Wether Condition
# rain              Breezy and foggy starting in the evening.
# ...

# %%
data.groupby("Wether Condition").max()
# Out:
#                                  Formatted Date                  Summary  \
# Wether Condition
# rain              2016-12-31 20:00:00.000 +0100  Windy and Partly Cloudy
# snow              2016-12-31 23:00:00.000 +0100       Windy and Overcast
#
#                   Temperature (C)  Apparent Temperature (C)  Humidity  \
# Wether Condition
# rain                    39.905556                 39.344444       1.0
# snow                     0.000000                  0.000000       1.0
#
#                   Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# Wether Condition
# rain                        63.8526                     359             16.1
# snow                        44.8868                     359             16.1
#
#                   Pressure (millibars)               Daily Summary
# Wether Condition
# rain                           1042.38     Windy in the afternoon.
# snow                           1046.38  Partly cloudy until night.

# %%
data[data["Wether Condition"] =="rain"]
#data["Wether Condition"].value_counts()
# Out:
#                       Formatted Date        Summary Wether Condition  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy             rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy             rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy             rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy             rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy             rain
# ...                              ...            ...              ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy             rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy             rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy             rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy             rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy             rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
data[(data['Wether Condition'] == "rain") | (data["Visibility (km)"] == 15.5204)]
# Out:
#                       Formatted Date        Summary Wether Condition  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy             rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy             rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy             rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy             rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy             rain
# ...                              ...            ...              ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy             rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy             rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy             rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy             rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy             rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
result1 = data.loc[:5:2,"Humidity":"Visibility (km)":2]
result1
# Out:
#    Humidity  Wind Bearing (degrees)
# 0      0.89                     251
# 2      0.89                     204
# 4      0.83                     259

# %%
result2 = data[:6:2][["Humidity","Visibility (km)"]]
result2
# Out:
#    Humidity  Visibility (km)
# 0      0.89          15.8263
# 2      0.89          14.9569
# 4      0.83          15.8263

# %%
result1 == result2
# Out:
#    Humidity  Visibility (km)
# 0      True             True
# 2      True             True
# 4      True             True
